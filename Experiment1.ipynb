# %% [markdown]
# **Name of the Experiment** : Introduction to Python
# Aim : Following are the aim of Today's Experiment :
# 1) To study multiple methods of Variable Declaration
# 2) To Detect the Datatype of a Variable using "Type" Keyword
# 3) To Perform Arithmatic Operations on Variables
# 4) To declare a User-Defined Variable
# 5) To calculate the Area of a Circle
# 6) To calculate Log Values
# 7) To calculate the Trignometric Value
# 8) To compare two Numbers
# 9) To compare two Numbers (User-Defined)
# **Name** : Pranav Menon
# **PRN.No** : 25070123085
# **Batch** : ENTC - B1

# %%
# Variable Declaration
x,y,z = "apple","orange","cherry"
print(x,y,z,sep = "\n")
# Out:
# apple
# orange
# cherry

# %%
# To Detect the Datatype of a Variable
x,y,z,w = 2,2.5,"Pranav",True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# To Perform Arithmatic Operations on Variables
a = 10
b = 5
add = a + b
sub = a - b
product = a*b
Quotient = a/b
Exp = 10**5
print(add,sub,product,Quotient,Exp,sep = "\n")
print(a + b,a - b,a*b,a/b)
print("The addition of the Two Numbers are : " , add)
print("The subtraction of the Two Numbers are : " , sub)
print("The Product of the Two Numbers are : " , product)
print("The Quotient of the Two Numbers are : " , Quotient)
print("The Exponential value of the Two Numbers are : " , Exp)
print("The addition,subtraction,Product,Quotient and Exponential value Respectively are : " ,a + b,a - b,a*b,a/b,a**b)
print("The addition,subtraction,Product,Quotient and Exponential value Respectively are : " ,a + b,a - b,a*b,a/b,a**b,sep="\n")
# Out:
# 15
# 5
# 50
# 2.0
# 100000
# 15 5 50 2.0
# The addition of the Two Numbers are :  15
# The subtraction of the Two Numbers are :  5
# The Product of the Two Numbers are :  50
# The Quotient of the Two Numbers are :  2.0
# The Exponential value of the Two Numbers are :  100000
# The addition,subtraction,Product,Quotient and Exponential value Respectively are :  15 5 50 2.0 100000
# The addition,subtraction,Product,Quotient and Exponential value Respectively are :
# 15
# 5
# 50
# 2.0
# 100000

# %%
# To declare a User-Defined Variable
a = int(input("Enter the First Number : "))
b = int(input("Enter the Second Number : "))
print("Add = ",a+b,"\n","Sub = ",a-b,"\n","Product = ",a*b,"\n","Quotient = ",a/b,"\n","Exponential value = ",a**b)
# Out:
# Enter the First Number : 10
# Enter the Second Number : 5
# Add =  15
#  Sub =  5
#  Product =  50
#  Quotient =  2.0
#  Exponential value =  100000

# %%
# To calculate the Area of a Circle
import math
R = (float(input("Enter the Radius of the Circle : ")))
area = (math.pi*(R**2))
print("The Area of the Circle is : ",area)
# Out:
# Enter the Radius of the Circle : 5
# The Area of the Circle is :  78.53981633974483

# %%
# To calculate Log Values
import math
print ("The Log of 10 to the base of 10 is : ")
print (math.log10(10))
# Out:
# The Log of 10 to the base of 10 is :
# 1.0

# %%
# To calculate the Trignometric Value
import math
print(math.sin(math.pi/3))
# Out:
# 0.8660254037844386

# %%
# To compare two Numbers
a = 10
b = 5
c = b<a
if c:
  print("b is lesser than a")
else:
  print("a is greater than b")
# Out:
# b is lesser than a

# %%
# To compare two Numbers (User-Defined)
a = float(input("Enter the value of A : "))
b = float(input("Enter the value of B : "))
res = a>b
if res:
  print("A is Greater than B")
else:
  print("B is Greater than A")
# Out:
# Enter the value of A : 8.9
# Enter the value of B : 1.4
# A is Greater than B
